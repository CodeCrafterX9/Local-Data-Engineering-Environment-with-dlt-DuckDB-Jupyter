# %%
import pandas as pd
import duckdb
import dlt
import numpy as np

print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %%
# Read CSV 
path = "../data/sample.csv"
def read_data(path):
    df = pd.read_csv(path)
    return df

df = read_data(path) 
df.head()
# Out:
#    order_id  product     category region  quantity  price  revenue
# 0       1.0   Laptop  Electronics  North         2  50000   100000
# 1       2.0    Phone  Electronics  South         3  20000    60000
# 2       3.0     Desk    Furniture   West         1  10000    10000
# 3       4.0    Chair    Furniture   East         4   3000    12000
# 4       5.0  Monitor  Electronics  North         2  15000    30000

# %%
df.dtypes
# Out:
# order_id    float64
# product         str
# category        str
# region          str
# quantity      int64
# price         int64
# revenue       int64
# dtype: object

# %%
def transform_data(df):
    #to remove entries with null values 
    df["remarks"]=np.where(df["order_id"].isna(),"invalid","valid")

    removed = df[df["remarks"]=="invalid"]
    df = df[df["remarks"]=="valid"]
    
    df["order_id"]=df["order_id"].astype("int")
    df["order_id"]=df["order_id"].astype("string")

    columns = ["quantity","price","revenue"]

    for col in columns :
        df[col]=df[col].astype("float")
        df[col]=df[col].abs()

    columns = ["product","category","region"]

    for col in columns :
        df[col]=df[col].fillna("Unknown")

    print("Data transformations completed successfully!")
    
    print(df)
    print(removed)

    return df
    
cleaned_data=transform_data(df)
cleaned_data = cleaned_data.to_dict(orient="records")
# Out:
# Data transformations completed successfully!
#   order_id   product     category region  quantity    price   revenue remarks
# 0        1    Laptop  Electronics  North       2.0  50000.0  100000.0   valid
# 1        2     Phone  Electronics  South       3.0  20000.0   60000.0   valid
# 2        3      Desk    Furniture   West       1.0  10000.0   10000.0   valid
# 3        4     Chair    Furniture   East       4.0   3000.0   12000.0   valid
# 4        5   Monitor  Electronics  North       2.0  15000.0   30000.0   valid
# 5        6    Tablet  Electronics  South       1.0  25000.0   25000.0   valid
# 6        7      Sofa    Furniture   West       1.0  40000.0   40000.0   valid
# 7        8  Keyboard  Electronics   East       5.0   1000.0    5000.0   valid
# 8        9     Mouse  Electronics  North      10.0    500.0    5000.0   valid
# 9       10   Printer  Electronics  South       2.0   8000.0   16000.0   valid
#     order_id  product     category region  quantity  price  revenue  remarks
# 10       NaN  Printer  Electronics  South         2   8000    16000  invalid

# %%
print(cleaned_data)
# Out:
# [{'order_id': '1', 'product': 'Laptop', 'category': 'Electronics', 'region': 'North', 'quantity': 2.0, 'price': 50000.0, 'revenue': 100000.0, 'remarks': 'valid'}, {'order_id': '2', 'product': 'Phone', 'category': 'Electronics', 'region': 'South', 'quantity': 3.0, 'price': 20000.0, 'revenue': 60000.0, 'remarks': 'valid'}, {'order_id': '3', 'product': 'Desk', 'category': 'Furniture', 'region': 'West', 'quantity': 1.0, 'price': 10000.0, 'revenue': 10000.0, 'remarks': 'valid'}, {'order_id': '4', 'product': 'Chair', 'category': 'Furniture', 'region': 'East', 'quantity': 4.0, 'price': 3000.0, 'revenue': 12000.0, 'remarks': 'valid'}, {'order_id': '5', 'product': 'Monitor', 'category': 'Electronics', 'region': 'North', 'quantity': 2.0, 'price': 15000.0, 'revenue': 30000.0, 'remarks': 'valid'}, {'order_id': '6', 'product': 'Tablet', 'category': 'Electronics', 'region': 'South', 'quantity': 1.0, 'price': 25000.0, 'revenue': 25000.0, 'remarks': 'valid'}, {'order_id': '7', 'product': 'Sofa', 'category': 'Furniture', 'region': 'West', 'quantity': 1.0, 'price': 40000.0, 'revenue': 40000.0, 'remarks': 'valid'}, {'order_id': '8', 'product': 'Keyboard', 'category': 'Electronics', 'region': 'East', 'quantity': 5.0, 'price': 1000.0, 'revenue': 5000.0, 'remarks': 'valid'}, {'order_id': '9', 'product': 'Mouse', 'category': 'Electronics', 'region': 'North', 'quantity': 10.0, 'price': 500.0, 'revenue': 5000.0, 'remarks': 'valid'}, {'order_id': '10', 'product': 'Printer', 'category': 'Electronics', 'region': 'South', 'quantity': 2.0, 'price': 8000.0, 'revenue': 16000.0, 'remarks': 'valid'}]

# %%
#isse humari ek data pipeline ban jaegi --> 

data_load_pipeline = dlt.pipeline(
    pipeline_name = "data_load_pipeline",
    destination = "duckdb", #ye aapka db type hoga :-> postgres/duckdb/snowflake/bigquery
    dataset_name = "sales_data"
)


data_load_pipeline.run(
    cleaned_data, 
    table_name = "sales"
)
# Out:
# LoadInfo(pipeline=<dlt.pipeline(pipeline_name='data_load_pipeline', destination='duckdb', dataset_name='sales_data', default_schema_name='data_load', schema_names=['data_load'], first_run=False, dev_mode=False, is_active=True, pipelines_dir='/home/codespace/.dlt/pipelines', working_dir='/home/codespace/.dlt/pipelines/data_load_pipeline')>, metrics={'1780992300.1358032': [{'started_at': DateTime(2026, 6, 9, 8, 5, 0, 250186, tzinfo=Timezone('UTC')), 'finished_at': DateTime(2026, 6, 9, 8, 5, 0, 483143, tzinfo=Timezone('UTC')), 'job_metrics': {'sales.a207c136f0.insert_values.gz': LoadJobMetrics(job_id='sales.a207c136f0.insert_values.gz', file_path='/home/codespace/.dlt/pipelines/data_load_pipeline/load/normalized/1780992300.1358032/started_jobs/sales.a207c136f0.0.insert_values.gz', table_name='sales', started_at=DateTime(2026, 6, 9, 8, 5, 0, 375505, tzinfo=Timezone('UTC')), finished_at=DateTime(2026, 6, 9, 8, 5, 0, 401706, tzinfo=Timezone('UTC')), state='completed', remote_url=None, retry_count=0, followup_jobs=None), '_dlt_pipeline_state.d3a1e1e98f.insert_values.gz': LoadJobMetrics(job_id='_dlt_pipeline_state.d3a1e1e98f.insert_values.gz', file_path='/home/codespace/.dlt/pipelines/data_load_pipeline/load/normalized/1780992300.1358032/started_jobs/_dlt_pipeline_state.d3a1e1e98f.0.insert_values.gz', table_name='_dlt_pipeline_state', started_at=DateTime(2026, 6, 9, 8, 5, 0, 376887, tzinfo=Timezone('UTC')), finished_at=DateTime(2026, 6, 9, 8, 5, 0, 398461, tzinfo=Timezone('UTC')), state='completed', remote_url=None, retry_count=0, followup_jobs=None)}, 'dataset_name': 'sales_data'}]}, destination_type='dlt.destinations.duckdb', destination_displayable_credentials='duckdb:////workspaces/Local-Data-Engineering-Environment-with-dlt-DuckDB-Jupyter/notebooks/data_load_pipeline.duckdb', destination_name='duckdb', environment=None, staging_type=None, staging_name=None, staging_displayable_credentials=None, destination_fingerprint='', dataset_name='sales_data', loads_ids=['1780992300.1358032'], load_packages=[LoadPackageInfo(load_id='1780992300.1358032', package_path='/home/codespace/.dlt/pipelines/data_load_pipeline/load/loaded/1780992300.1358032', state='loaded', schema=<dlt.Schema(name='data_load', version=2, tables=['_dlt_version', '_dlt_loads', 'sales', '_dlt_pipeline_state'], version_hash='pqMoYdhffXMt3XEpMUAgwx5nq9wzGkwc9nRbaXbvWKI=')>, schema_update={'_dlt_version': {'name': '_dlt_version', 'columns': {'version': {'name': 'version', 'data_type': 'bigint', 'nullable': False}, 'engine_version': {'name': 'engine_version', 'data_type': 'bigint', 'nullable': False}, 'inserted_at': {'name': 'inserted_at', 'data_type': 'timestamp', 'nullable': False}, 'schema_name': {'name': 'schema_name', 'data_type': 'text', 'nullable': False}, 'version_hash': {'name': 'version_hash', 'data_type': 'text', 'nullable': False}, 'schema': {'name': 'schema', 'data_type': 'text', 'nullable': False}}, 'write_disposition': 'skip', 'resource': '_dlt_version', 'description': 'Created by DLT. Tracks schema updates'}, '_dlt_pipeline_state': {'columns': {'version': {'name': 'version', 'data_type': 'bigint', 'nullable': False}, 'engine_version': {'name': 'engine_version', 'data_type': 'bigint', 'nullable': False}, 'pipeline_name': {'name': 'pipeline_name', 'data_type': 'text', 'nullable': False}, 'state': {'name': 'state', 'data_type': 'text', 'nullable': False}, 'created_at': {'name': 'created_at', 'data_type': 'timestamp', 'nullable': False}, 'version_hash': {'name': 'version_hash', 'data_type': 'text', 'nullable': True}, '_dlt_load_id': {'name': '_dlt_load_id', 'data_type': 'text', 'nullable': False, 'precision': 64}, '_dlt_id': {'name': '_dlt_id', 'data_type': 'text', 'nullable': False, 'unique': True, 'row_key': True}}, 'write_disposition': 'append', 'file_format': 'preferred', 'name': '_dlt_pipeline_state', 'resource': '_dlt_pipeline_state', 'x-normalizer': {'seen-data': True}}, '_dlt_loads': {'name': '_dlt_loads', 'columns': {'load_id': {'name': 'load_id', 'data_ ...
